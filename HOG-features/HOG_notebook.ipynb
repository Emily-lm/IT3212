# %% [markdown]
# ## HOG features

# %% [markdown]
# ### Testing method

# %%
# %load_ext autoreload
# %autoreload 2

import HOG_methods as hogg
import numpy as np
import matplotlib.pyplot as plt
import cv2
import skimage as ski
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load images

optimus = ski.io.imread('images/optimus.jpeg')
truck = ski.io.imread('images/truck.jpg')
bird = ski.io.imread('images/bird.jpg')
starship = ski.io.imread('images/starship.jpg')

images = [optimus, truck, bird, starship]

plt.imshow(optimus)

# %%
resized_img = ski.transform.resize(optimus, (128, 128))
plt.imshow(resized_img)

# %%
# creating hog features 

hogg.hog(resized_img, (8,8), (2,2), 9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # creating hog features
# ----> 3 hogg.hog(resized_img, (8,8), (2,2), 9)
#
# File ~/Desktop/IT3212 - Datadrevet Programvare/IT3212/HOG-features/HOG_methods.py:83, in hog(img, cell_size, block_size, nbins)
#      81                 cell_mag = mag[i*cell_h:(i+1)*cell_h, j*cell_w:(j+1)*cell_w]
#      82                 cell_ang = ang[i*cell_h:(i+1)*cell_h, j*cell_w:(j+1)*cell_w]
# ---> 83                 hog_img[i, j, k, l, :] = cell_hog(cell_mag, cell_ang, cell_size, nbins)
#      85 return img, mag, hog_img
#
# File ~/Desktop/IT3212 - Datadrevet Programvare/IT3212/HOG-features/HOG_methods.py:27, in cell_hog(mag, ang, cell_size, nbins)
#      24 magnitude = mag[i, j]
#      26 # Compute bin index
# ---> 27 bin_index = int(angle / (2 * np.pi / nbins))
#      29 # Update histogram
#      30 hog_cell[bin_index] += magnitude
#
# TypeError: only length-1 arrays can be converted to Python scalars
