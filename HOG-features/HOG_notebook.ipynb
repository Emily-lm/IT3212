# %% [markdown]
# ## HOG features

# %% [markdown]
# ### Testing method

# %%
# %load_ext autoreload
# %autoreload 2
# Imports
import HOG_methods as hogg
import numpy as np
import matplotlib.pyplot as plt
import cv2
import skimage as ski
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load images

optimus = ski.io.imread('images/optimus.jpeg')
truck = ski.io.imread('images/truck.jpg')
bird = ski.io.imread('images/bird.jpg')
starship = ski.io.imread('images/starship.jpg')

images = [optimus, truck, bird, starship]

plt.imshow(optimus)

# %%
#resized_img = ski.transform.resize(optimus, (128, 128))
resized_img = optimus
plt.imshow(resized_img)

# %%
# creating hog features 

img, mag_normalized, hog_img= hogg.hog(optimus, (8,8), (2,2), 9)

plt.imshow(mag_normalized, cmap='gray')

# %%
hog_img.shape
# Out:
# (89, 159, 2, 2, 9)

# %%
hogg.visualize_hog(optimus, hog_img)
